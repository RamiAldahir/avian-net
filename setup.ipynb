# %% [markdown]
# # This notebook is used to gather the dataset, preprocess it, train a model, then run the detection

# %% [markdown]
# Remove any existing recordings and download the bird song recordings from Xeno-Canto.

# %%
# !python -u dataset/clean_dataset.py
# !python -u dataset/download_xeno.py

# %% [markdown]
# Preprocess the dataset that has been imported.

# %%
# !python -u training/preprocess.py

# %% [markdown]
# Train a tensorflow model and generate reports.

# %%
# !python -u training/train.py
# !python -u training/evaluate.py

# %% [markdown]
# Run the detection

# %%
# !python -u app.py
# Out:
# ^C
